# %% [markdown]
# # UNH-RVAT baseline performance and near-wake measurements

# %% [markdown]
# This notebook gives examples on how to use the data processing and plotting functions.

# %%
# %matplotlib inline
from plotting import *

# Set matplotlib parameters to use LaTeX, larger fonts, etc. 
#setpltparams()

# Plot contours of mean streamwise velocity
plotwake("meanucont")

# %% [markdown]
# ## Plot names and descriptions

# %% [markdown]
# | Name | Description |
# |------|-------------|
# | `meanucont` | Contours of mean velocity $U$ |
# | `v-wquiver` | Vectors of mean cross-stream and vertical velocities $V$ and $W$ |
#
# Lists of plots can be generated by giving a list of names to the `plotwake` function:

# %%
plotlist = ["meanu_2tsrs", "stdu_2tsrs", "stdv_2tsrs"]

plotwake(plotlist)

# %% [markdown]
# ## Generate performance figure

# %%
plotperf()
# Out:
# At tsr = 1.9, C_P = 0.257553502869 ; C_D = 0.964349975716
